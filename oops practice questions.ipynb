# %% [markdown]
# 1. Create a class Employee with:
#
# name
# salary
# display() method
#
# Create a subclass Manager that:
#
# Inherits from Employee
# Has an additional attribute department
# Overrides display()
#
# Expected output:
#
# Name: Rahul
# Salary: 60000
# Department: IT
#
# Task: Write the complete program demonstrating inheritance and polymorphism.

# %% [markdown]
# 2. Write a generator function even_numbers(n) that generates all even numbers from 0 up to 10.

# %%
3. A company has a list of employee salaries:

salaries = [25000, 45000, 30000, 60000, 75000]

Create a generator function high_salary() that yields only salaries greater than 40000.

Expected output:

45000
60000
75000

# %% [markdown]
# 4. Create a BankAccount class with a private attribute __balance.
#
# Implement methods to:
#
# Deposit money
# Withdraw money
# Display the current balance
#
# Create an object and perform at least two transactions.

# %% [markdown]
# 5. Create a base class Employee with attributes name and salary and a method display().
#
# Create a subclass Developer with an additional attribute language.
#
# Create an object of Developer and display all the details.

# %% [markdown]
# 6. Polymorphism Example.
# Create three classes:
#
# CreditCard
# UPI
# NetBanking
#
# Each class should have a method called pay(amount).
#
# The method should display a different message depending on the payment method.
#
# For example:
#
# Paid ₹500 using Credit Card
# Paid ₹1000 using UPI
# Paid ₹2000 using Net Banking
#
# Use a loop to call pay() for different objects.

# %% [markdown]
# 7. Create a generator function multiplication_table(n) that generates the first 10 multiples of a given number.
